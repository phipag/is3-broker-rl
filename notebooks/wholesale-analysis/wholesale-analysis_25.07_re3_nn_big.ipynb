# %%
# Parameters
COMMENTS = "BigNN,RewardNorm,Re3,NoTariffRL"

# %%
import pandas as pd
import numpy as np
import os
import json
import seaborn as sns
import is3_broker_rl
import matplotlib.pyplot as plt
from pathlib import Path

# %%
DATA_DIR = Path(is3_broker_rl.__file__).parent.parent / "data"

# %%
# Papermill parameter cell
# Name of the directory to analyse. Should contain consumption_action.csv and consumption_reward.csv.
ANALYSIS_DIR_NAME = ""

# %%
print(COMMENTS)
# Out:
# BigNN,RewardNorm,Re3,NoTariffRL

# %%
#path = "../data/"
reward_prefix = "wholesale_reward.csv"

# %%
ANALYSIS_DIR = DATA_DIR / ANALYSIS_DIR_NAME

# %% [markdown]
# ### Reward analysis

# %%
df_reward = pd.read_csv(os.path.join(ANALYSIS_DIR,reward_prefix))

# %%
# Fixes the issue that the experiment scheduler always assigns the same gameId
def write_unique_game_id(df):
    new_game_start_indices = df[df["timeslot"] < df["timeslot"].shift()].index
    if len(new_game_start_indices) > 0:
        df.loc[: new_game_start_indices[0], "gameId"] = f"game0"
        for i in range(len(new_game_start_indices) - 1):
            df.loc[new_game_start_indices[i] : new_game_start_indices[i + 1], "gameId"] = f"game{i + 1}"
        df.loc[new_game_start_indices[-1] :, "gameId"] = f"game{len(new_game_start_indices)}"

# %%
def min_max_scaler(series):
    return (series - series.min()) / (series.max() - series.min())

# %%
df_reward.dropna(inplace=True) # Drop first few timesteps that have no action. 
df_reward2 = df_reward["observation"].apply(json.loads)
col_names = list(df_reward2.iloc[0].keys())
df_reward2 = df_reward2.apply(lambda x: list(x.values()))
temp_list = []
for row in df_reward2:

    temp_list.append(row)

temp_df = pd.DataFrame(temp_list, columns=col_names)

temp_merge_df = pd.DataFrame()
temp_name = []
for column in temp_df.columns:
    if type(temp_df[column].iloc[0]) == list:
        temp_df2 = temp_df[column].apply(pd.Series)
        i=0
        for column2 in temp_df2:
            temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
            i+=1
            
        
    else:
        temp_merge_df[column] = temp_df[column]
    
col_names = []
price = []
energy = []
for i in range(24):
    col_names.append(f"energy_{i+1}")
    col_names.append(f"price_{i+1}")
    price.append(f"price_{i+1}")
    energy.append(f"energy_{i+1}")
# Out:
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# ...
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]
# /tmp/ipykernel_24655/1597897593.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   temp_merge_df[f"{column}_{i}"] = temp_df2[column2]

# %%
df_action = df_reward.apply(lambda x: x["last_action"].split(";"), result_type="expand", axis=1).drop(0, axis=1)
df_action = df_action.astype(float)
df_action.columns = col_names
action_observation_reward_df = pd.concat([df_action,temp_merge_df, df_reward[["reward", "balancing_reward", "wholesale_reward","shaped_return","sum_mWh"]]],axis=1)
write_unique_game_id(action_observation_reward_df)
df = action_observation_reward_df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Columns: 352 entries, energy_1 to sum_mWh
# dtypes: float64(349), int64(2), object(1)
# memory usage: 148.6+ KB

# %%
df[df["customer_count"].shift(1) -df["customer_count"] > 8000 | (df["customer_count"].shift(1) -df["customer_count"] < 8000)]["customer_count"]
# Out:
# 17    54983
# 23    53641
# 29    52483
# Name: customer_count, dtype: int64

# %%
df.iloc[5300:8000][["customer_count","reward","balancing_reward", "wholesale_reward","shaped_return","customer_count"]].tail(50)
# Out:
# Empty DataFrame
# Columns: [customer_count, reward, balancing_reward, wholesale_reward, shaped_return, customer_count]
# Index: []

# %%
df[df["reward"]< -0.3 ]
# Out:
# Empty DataFrame
# Columns: [energy_1, price_1, energy_2, price_2, energy_3, price_3, energy_4, price_4, energy_5, price_5, energy_6, price_6, energy_7, price_7, energy_8, price_8, energy_9, price_9, energy_10, price_10, energy_11, price_11, energy_12, price_12, energy_13, price_13, energy_14, price_14, energy_15, price_15, energy_16, price_16, energy_17, price_17, energy_18, price_18, energy_19, price_19, energy_20, price_20, energy_21, price_21, energy_22, price_22, energy_23, price_23, energy_24, price_24, gameId, timeslot, p_grid_imbalance_0, p_grid_imbalance_1, p_grid_imbalance_2, p_grid_imbalance_3, p_grid_imbalance_4, p_grid_imbalance_5, p_grid_imbalance_6, p_grid_imbalance_7, p_grid_imbalance_8, p_grid_imbalance_9, p_grid_imbalance_10, p_grid_imbalance_11, p_grid_imbalance_12, p_grid_imbalance_13, p_grid_imbalance_14, p_grid_imbalance_15, p_grid_imbalance_16, p_grid_imbalance_17, p_grid_imbalance_18, p_grid_imbalance_19, p_grid_imbalance_20, p_grid_imbalance_21, p_grid_imbalance_22, p_grid_imbalance_23, p_customer_prosumption_0, p_customer_prosumption_1, p_customer_prosumption_2, p_customer_prosumption_3, p_customer_prosumption_4, p_customer_prosumption_5, p_customer_prosumption_6, p_customer_prosumption_7, p_customer_prosumption_8, p_customer_prosumption_9, p_customer_prosumption_10, p_customer_prosumption_11, p_customer_prosumption_12, p_customer_prosumption_13, p_customer_prosumption_14, p_customer_prosumption_15, p_customer_prosumption_16, p_customer_prosumption_17, p_customer_prosumption_18, p_customer_prosumption_19, p_customer_prosumption_20, p_customer_prosumption_21, p_customer_prosumption_22, p_customer_prosumption_23, p_wholesale_price_0, p_wholesale_price_1, ...]
# Index: []
#
# [0 rows x 352 columns]

# %%
df_reward_rolling = df_reward["reward"].rolling(20).mean().dropna()
df_balancing_reward = df_reward["balancing_reward"].rolling(5).mean().dropna()
df_wholesale_reward = df_reward["wholesale_reward"].rolling(5).mean().dropna()
df_tariff_reward = df_reward["tariff_reward"].rolling(1).mean().dropna()
#df_shaped = df_reward["shaped_return"].rolling(20).mean().dropna()

# %%
sns.set_theme()
sns.axes_style("darkgrid")
f, axs = plt.subplots(3, 1, sharex=True)



#graph5 = sns.lineplot(x=df_tariff_reward.index, y=df_tariff_reward, ax=axs, label="Tariff_reward")
#graph6 = sns.lineplot(x=df_shaped.index, y=df_shaped, ax=axs, label="Shaped_reward", color="green")

graph7 = sns.lineplot(x=df_reward.index, y=df_reward["reward"].rolling(5).mean(), color="orange", ax=axs[0], alpha=0.4, label="Reward")
graph4 = sns.lineplot(x=df_wholesale_reward.index, y=df_wholesale_reward, ax=axs[0],label="Wholesale_reward")
graph3 = sns.lineplot(x=df_balancing_reward.index, y=df_balancing_reward, ax=axs[0], label="Balancing_reward")
graph2 = sns.lineplot(x=df_reward_rolling.index, y=df_reward_rolling, ax=axs[0], label="Total_mean_reward", linewidth= 3.5)
graph8 = sns.regplot(x=df_reward_rolling.index, y=df_reward_rolling, marker="", label="reward_regression", ax=axs[0])
graph9 = sns.lineplot(x=df.index, y=min_max_scaler(df["sum_mWh"]).rolling(5).mean(), data=df, ax=axs[1])
graph9 = sns.lineplot(x=df.index, y=min_max_scaler(df["reward"]).rolling(5).mean(), data=df, ax=axs[1])
sns.lineplot(x=df.index, y=min_max_scaler(df["balancing_reward"]).rolling(5).mean(), data=df, ax=axs[2])
sns.lineplot(x=df.index, y=min_max_scaler(df["customer_count"]), data=df, ax=axs[2])


for ax in axs:
    ax.vlines(
            df[df["gameId"].shift() != df["gameId"]].index,
            0,
            1,
            transform=ax.get_xaxis_transform(),
            colors="r",
            alpha=0.9,
            label="New game",
        )
axs[0].legend()
axs[1].set_ylabel("sum_mWh")
axs[0].set_ybound(-0.4,0.05)
f.set_figwidth(30)
f.set_figheight(20)

# %%
df.iloc[df.index < 2365]["cleared_orders_energy_23"].max()
# Out:
# 49.785621643066406

# %%
df["timeslot"]
# Out:
# 0         362
# 1         363
# 2         364
# 3         365
# 4         366
#          ...
# 13708    1833
# 13709    1834
# 13710    1835
# 13711    1836
# 13712    1837
# Name: timeslot, Length: 13713, dtype: int64

# %%
# Or just use shift?
index_slot = 201
col_names_temp = ["reward", "customer_count"]
templist = []
for i in range(24):
    energy_price_bid = df.iloc[(index_slot - i)][[f"energy_{i+1}",f"price_{i+1}"]].values
    trade_result = df.iloc[index_slot - i +1][[f"cleared_orders_energy_{i}", f"cleared_orders_price_{i}"]].values
    market_position = df.iloc[index_slot -i+1][f"market_position_{i}"]
    sum_mwh = df.iloc[index_slot +1]["sum_mWh"]
    index_slot_list = df.iloc[index_slot-i+1].name
    predicted_prosumption=df.iloc[index_slot-i+1][f"p_customer_prosumption_{i}"]/1000
    #if i = 0:
    #    trade_result[0] = df.iloc[timeslot]["final"]
    templist.append([*energy_price_bid, *trade_result, market_position, sum_mwh, index_slot_list, predicted_prosumption])

df_action_analysis = pd.DataFrame(templist, columns=["energy_action", "price_action", "energy_trade_order", "price_trade_order", "market_position", "sum_mWh", "index_slot", "predicted_prosumption"])
df_action_analysis
# Out:
#     energy_action  price_action  energy_trade_order  price_trade_order  \
# 0       -9.722677     91.030020            0.000000           0.000000
# 1       27.833503    -33.908385           18.699944         -42.375596
# 2      -15.452641     99.518985            0.000000           0.000000
# 3       -5.799964     75.544775            0.000000           0.000000
# 4       15.685946    -47.051772           10.271419         -41.408869
# 5      -47.155410     84.497130           30.435198         -39.115592
# 6      -10.135293     84.582937            0.000000           0.000000
# 7       42.803210    -90.490073           -4.566959          22.854551
# 8      -49.611336     49.222794           -5.835647          15.372207
# 9       48.199612    -31.079626            8.795458         -38.612699
# 10     -22.070962     43.129924            0.000000           0.000000
# 11       1.639915    -27.068597            0.000000           0.000000
# 12     -38.929945     40.935358            2.121513         -18.131442
# 13      32.372105    -36.648762            0.000000           0.000000
# 14      33.406347    -40.678477            0.000000           0.000000
# 15      42.598951    -17.043087            0.000000           0.000000
# 16      16.483253    -31.452382            0.000000           0.000000
# 17       5.273980    -50.962317            0.617445          -0.869831
# 18      28.145975    -78.187156            1.040366         -18.572157
# 19      19.803393    -37.762943            3.873692         -38.236937
# 20      36.196065    -76.683676            1.259197         -20.760121
# 21      41.736680    -72.874069            1.716377         -16.798550
# 22     -38.363028      2.604270            0.000000           0.000000
# 23     -44.875962     69.158030            0.000000           0.000000
#
#     market_position    sum_mWh  index_slot  predicted_prosumption
# 0         67.630117  55.390514         202             -10.258062
# 1         67.630117  55.390514         201              -8.635391
# 2         48.930173  55.390514         200             -10.010097
# 3         48.930173  55.390514         199             -10.200062
# 4         48.930173  55.390514         198              -9.990668
# 5         38.658754  55.390514         197              -9.347996
# 6          8.223557  55.390514         196              -8.425037
# 7          8.223557  55.390514         195              -6.646145
# 8         14.321028  55.390514         194              -5.388889
# 9         21.367537  55.390514         193              -4.574760
# 10        12.572079  55.390514         192              -4.842571
# 11        12.572079  55.390514         191              -5.015509
# 12        12.572079  55.390514         190              -4.836603
# 13        10.450566  55.390514         189              -5.799038
# 14        10.450566  55.390514         188              -4.827602
# 15        10.450566  55.390514         187              -6.812497
# 16        10.450566  55.390514         186              -6.706538
# 17        10.450566  55.390514         185              -7.386577
# 18         9.833122  55.390514         184              -5.872383
# 19         8.792755  55.390514         183              -7.868883
# 20         2.975574  55.390514         182              -7.239072
# 21         1.716377  55.390514         181              -6.008627
# 22         0.000000  55.390514         180              -5.490776
# 23         0.000000  55.390514         179              -4.923133

# %%
df_action_analysis.style.background_gradient(cmap="bwr")
# Out:
# <style type="text/css">
# #T_e5120_row0_col0 {
#   background-color: #d0d0ff;
#   color: #000000;
# }
# #T_e5120_row0_col1, #T_e5120_row1_col6, #T_e5120_row12_col7, #T_e5120_row14_col7 {
#   background-color: #ff1616;
#   color: #f1f1f1;
# }
# #T_e5120_row0_col2, #T_e5120_row2_col2, #T_e5120_row3_col2, #T_e5120_row6_col2, #T_e5120_row10_col2, #T_e5120_row11_col2, #T_e5120_row13_col2, #T_e5120_row14_col2, #T_e5120_row15_col2, #T_e5120_row16_col2, #T_e5120_row22_col2, #T_e5120_row23_col2 {
#   background-color: #5252ff;
#   color: #f1f1f1;
# }
# #T_e5120_row0_col3, #T_e5120_row2_col3, #T_e5120_row3_col3, #T_e5120_row6_col3, #T_e5120_row8_col6, #T_e5120_row10_col3, #T_e5120_row11_col3, #T_e5120_row13_col3, #T_e5120_row14_col3, #T_e5120_row15_col3, #T_e5120_row16_col3, #T_e5120_row22_col3, #T_e5120_row23_col3 {
#   background-color: #ffb2b2;
#   color: #000000;
# }
# #T_e5120_row0_col4, #T_e5120_row0_col6, #T_e5120_row1_col4, #T_e5120_row2_col1, #T_e5120_row5_col2, #T_e5120_row7_col3, #T_e5120_row9_col0, #T_e5120_row9_col7 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_e5120_row0_col5, #T_e5120_row0_col7, #T_e5120_row1_col3, #T_e5120_row1_col5, #T_e5120_row2_col5, #T_e5120_row3_col5, #T_e5120_row4_col5, #T_e5120_row5_col5, #T_e5120_row6_col5, #T_e5120_row7_col1, #T_e5120_row7_col5, #T_e5120_row8_col0, #T_e5120_row8_col2, #T_e5120_row8_col5, #T_e5120_row9_col5, #T_e5120_row10_col5, #T_e5120_row11_col5, #T_e5120_row12_col5, #T_e5120_row13_col5, #T_e5120_row14_col5, #T_e5120_row15_col5, #T_e5120_row16_col5, #T_e5120_row17_col5, #T_e5120_row18_col5, #T_e5120_row19_col5, #T_e5120_row20_col5, #T_e5120_row21_col5, #T_e5120_row22_col4, #T_e5120_row22_col5, #T_e5120_row23_col4, #T_e5120_row23_col5, #T_e5120_row23_col6 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_e5120_row1_col0 {
#   background-color: #ff6a6a;
#   color: #f1f1f1;
# }
# #T_e5120_row1_col1 {
#   background-color: #9898ff;
#   color: #f1f1f1;
# }
# #T_e5120_row1_col2 {
#   background-color: #ffa4a4;
#   color: #000000;
# }
# #T_e5120_row1_col7 {
#   background-color: #9292ff;
#   color: #f1f1f1;
# }
# #T_e5120_row2_col0, #T_e5120_row15_col6 {
#   background-color: #b2b2ff;
#   color: #000000;
# }
# #T_e5120_row2_col4, #T_e5120_row3_col4, #T_e5120_row4_col4 {
#   background-color: #ff8c8c;
#   color: #000000;
# }
# #T_e5120_row2_col6 {
#   background-color: #ff2c2c;
#   color: #f1f1f1;
# }
# #T_e5120_row2_col7, #T_e5120_row20_col4, #T_e5120_row22_col6 {
#   background-color: #1616ff;
#   color: #f1f1f1;
# }
# #T_e5120_row3_col0 {
#   background-color: #e4e4ff;
#   color: #000000;
# }
# #T_e5120_row3_col1 {
#   background-color: #ff4040;
#   color: #f1f1f1;
# }
# #T_e5120_row3_col6 {
#   background-color: #ff4242;
#   color: #f1f1f1;
# }
# #T_e5120_row3_col7 {
#   background-color: #0404ff;
#   color: #f1f1f1;
# }
# #T_e5120_row4_col0 {
#   background-color: #ffaaaa;
#   color: #000000;
# }
# #T_e5120_row4_col1 {
#   background-color: #7474ff;
#   color: #f1f1f1;
# }
# #T_e5120_row4_col2 {
#   background-color: #e2e2ff;
#   color: #000000;
# }
# #T_e5120_row4_col3 {
#   background-color: #0606ff;
#   color: #f1f1f1;
# }
# #T_e5120_row4_col6 {
#   background-color: #ff5858;
#   color: #f1f1f1;
# }
# #T_e5120_row4_col7, #T_e5120_row5_col3, #T_e5120_row23_col0 {
#   background-color: #1818ff;
#   color: #f1f1f1;
# }
# #T_e5120_row5_col0, #T_e5120_row21_col4 {
#   background-color: #0c0cff;
#   color: #f1f1f1;
# }
# #T_e5120_row5_col1, #T_e5120_row6_col1 {
#   background-color: #ff2828;
#   color: #f1f1f1;
# }
# #T_e5120_row5_col4 {
#   background-color: #ffdada;
#   color: #000000;
# }
# #T_e5120_row5_col6, #T_e5120_row13_col7 {
#   background-color: #ff6e6e;
#   color: #f1f1f1;
# }
# #T_e5120_row5_col7 {
#   background-color: #5050ff;
#   color: #f1f1f1;
# }
# #T_e5120_row6_col0, #T_e5120_row9_col2 {
#   background-color: #ceceff;
#   color: #000000;
# }
# #T_e5120_row6_col4, #T_e5120_row7_col4 {
#   background-color: #3e3eff;
#   color: #f1f1f1;
# }
# #T_e5120_row6_col6 {
#   background-color: #ff8484;
#   color: #f1f1f1;
# }
# #T_e5120_row6_col7 {
#   background-color: #a4a4ff;
#   color: #000000;
# }
# #T_e5120_row7_col0, #T_e5120_row15_col0 {
#   background-color: #ff1c1c;
#   color: #f1f1f1;
# }
# #T_e5120_row7_col2 {
#   background-color: #1010ff;
#   color: #f1f1f1;
# }
# #T_e5120_row7_col6 {
#   background-color: #ff9a9a;
#   color: #000000;
# }
# #T_e5120_row7_col7, #T_e5120_row17_col3 {
#   background-color: #ffbaba;
#   color: #000000;
# }
# #T_e5120_row8_col1 {
#   background-color: #ff8686;
#   color: #f1f1f1;
# }
# #T_e5120_row8_col3 {
#   background-color: #ff3a3a;
#   color: #f1f1f1;
# }
# #T_e5120_row8_col4 {
#   background-color: #6c6cff;
#   color: #f1f1f1;
# }
# #T_e5120_row8_col7 {
#   background-color: #ff4848;
#   color: #f1f1f1;
# }
# #T_e5120_row9_col1, #T_e5120_row9_col4 {
#   background-color: #a0a0ff;
#   color: #f1f1f1;
# }
# #T_e5120_row9_col3 {
#   background-color: #1c1cff;
#   color: #f1f1f1;
# }
# #T_e5120_row9_col6, #T_e5120_row15_col7 {
#   background-color: #ffc8c8;
#   color: #000000;
# }
# #T_e5120_row10_col0, #T_e5120_row13_col1 {
#   background-color: #9090ff;
#   color: #f1f1f1;
# }
# #T_e5120_row10_col1 {
#   background-color: #ff9696;
#   color: #000000;
# }
# #T_e5120_row10_col4, #T_e5120_row11_col4, #T_e5120_row12_col4 {
#   background-color: #5e5eff;
#   color: #f1f1f1;
# }
# #T_e5120_row10_col6 {
#   background-color: #ffdede;
#   color: #000000;
# }
# #T_e5120_row10_col7 {
#   background-color: #ff1818;
#   color: #f1f1f1;
# }
# #T_e5120_row11_col0 {
#   background-color: #fff2f2;
#   color: #000000;
# }
# #T_e5120_row11_col1 {
#   background-color: #aaaaff;
#   color: #000000;
# }
# #T_e5120_row11_col6 {
#   background-color: #fff4f4;
#   color: #000000;
# }
# #T_e5120_row11_col7 {
#   background-color: #ff2626;
#   color: #f1f1f1;
# }
# #T_e5120_row12_col0 {
#   background-color: #3636ff;
#   color: #f1f1f1;
# }
# #T_e5120_row12_col1 {
#   background-color: #ff9c9c;
#   color: #000000;
# }
# #T_e5120_row12_col2 {
#   background-color: #7070ff;
#   color: #f1f1f1;
# }
# #T_e5120_row12_col3 {
#   background-color: #bebeff;
#   color: #000000;
# }
# #T_e5120_row12_col6 {
#   background-color: #f4f4ff;
#   color: #000000;
# }
# #T_e5120_row13_col0, #T_e5120_row22_col7 {
#   background-color: #ff5252;
#   color: #f1f1f1;
# }
# #T_e5120_row13_col4, #T_e5120_row14_col4, #T_e5120_row15_col4, #T_e5120_row16_col4, #T_e5120_row17_col4 {
#   background-color: #4e4eff;
#   color: #f1f1f1;
# }
# #T_e5120_row13_col6 {
#   background-color: #dedeff;
#   color: #000000;
# }
# #T_e5120_row14_col0 {
#   background-color: #ff4c4c;
#   color: #f1f1f1;
# }
# #T_e5120_row14_col1 {
#   background-color: #8686ff;
#   color: #f1f1f1;
# }
# #T_e5120_row14_col6, #T_e5120_row21_col3 {
#   background-color: #c8c8ff;
#   color: #000000;
# }
# #T_e5120_row15_col1 {
#   background-color: #c4c4ff;
#   color: #000000;
# }
# #T_e5120_row16_col0 {
#   background-color: #ffa6a6;
#   color: #000000;
# }
# #T_e5120_row16_col1 {
#   background-color: #9e9eff;
#   color: #f1f1f1;
# }
# #T_e5120_row16_col6 {
#   background-color: #9a9aff;
#   color: #f1f1f1;
# }
# #T_e5120_row16_col7 {
#   background-color: #ffc0c0;
#   color: #000000;
# }
# #T_e5120_row17_col0 {
#   background-color: #ffe0e0;
#   color: #000000;
# }
# #T_e5120_row17_col1, #T_e5120_row21_col2 {
#   background-color: #6a6aff;
#   color: #f1f1f1;
# }
# #T_e5120_row17_col2 {
#   background-color: #5a5aff;
#   color: #f1f1f1;
# }
# #T_e5120_row17_col6 {
#   background-color: #8484ff;
#   color: #f1f1f1;
# }
# #T_e5120_row17_col7 {
#   background-color: #fffcfc;
#   color: #000000;
# }
# #T_e5120_row18_col0 {
#   background-color: #ff6868;
#   color: #f1f1f1;
# }
# #T_e5120_row18_col1, #T_e5120_row19_col3 {
#   background-color: #2020ff;
#   color: #f1f1f1;
# }
# #T_e5120_row18_col2 {
#   background-color: #6060ff;
#   color: #f1f1f1;
# }
# #T_e5120_row18_col3 {
#   background-color: #babaff;
#   color: #000000;
# }
# #T_e5120_row18_col4 {
#   background-color: #4a4aff;
#   color: #f1f1f1;
# }
# #T_e5120_row18_col6 {
#   background-color: #6e6eff;
#   color: #f1f1f1;
# }
# #T_e5120_row18_col7 {
#   background-color: #ff7474;
#   color: #f1f1f1;
# }
# #T_e5120_row19_col0 {
#   background-color: #ff9494;
#   color: #000000;
# }
# #T_e5120_row19_col1 {
#   background-color: #8e8eff;
#   color: #f1f1f1;
# }
# #T_e5120_row19_col2 {
#   background-color: #8888ff;
#   color: #f1f1f1;
# }
# #T_e5120_row19_col4, #T_e5120_row20_col6 {
#   background-color: #4242ff;
#   color: #f1f1f1;
# }
# #T_e5120_row19_col6 {
#   background-color: #5858ff;
#   color: #f1f1f1;
# }
# #T_e5120_row19_col

# %%
i = 0
index_slot = 201
df.iloc[index_slot][[*[f"cleared_orders_energy_{i}", f"cleared_orders_price_{i}"], f"market_position_{i}", "sum_mWh", f"p_customer_prosumption_{i}"]]
#[*[f"sum_mWh", "price_1"], *["price_2", "test3"]]
#[*["test", "test2"],*["test3", "test4"]]
# Out:
# cleared_orders_energy_0              0.0
# cleared_orders_price_0               0.0
# market_position_0              86.738881
# sum_mWh                        60.465687
# p_customer_prosumption_0   -10117.652344
# price_11  -58.584774  -5.187088  94.830179
# energy_12   1.570565   0.961417 -14.648628
# price_12  -78.540808 -11.570197  43.761036
# energy_13  13.050616  34.546900  34.427685
# price_13  -35.408866 -95.549703 -75.903761
# energy_14  30.432665  -4.233649  42.413157
# price_14   -2.070764   6.890732 -73.188287
# energy_15 -37.802288  -6.600931  34.035552
# price_15   14.532778  21.355942 -52.237386
# energy_16  42.397058 -32.401058  30.053473
# price_16  -33.146062  52.869403 -62.874365
# energy_17  27.953458 -48.218161  29.375553
# price_17   -7.884851  13.652351 -95.667082
# energy_18  35.948390  18.594974  13.296640
# price_18  -31.343752 -28.270841 -16.235608
# energy_19  23.920697 -40.735239  26.006126
# price_19  -93.675184  20.888272 -94.983864
# energy_20  15.401530  42.335224  25.350732
# price_20  -91.651046 -96.770233 -98.770189
# energy_21  37.771028  20.372719 -19.057584
# price_21  -64.009511 -17.359594  76.110929
# energy_22  19.692469 -22.698966   7.745606
# price_22  -64.115739  57.436025 -82.330012
# energy_23  41.113615 -23.565140  26.438713
# price_23  -90.526164  15.317395 -70.446998
# energy_24  46.654081 -46.307689 -36.246684
# price_24  -97.749841  95.874321  30.406475
#
# [48 rows x 30 columns]

# %%
energy_price_bid
# Out:
# array([-44.87596154212952, 69.15802955627441], dtype=object)

# %%
for index, value in df[df.columns.difference(pd.Index(["gameId"]))].corr()["reward"].sort_values().iteritems():
    
    print(index, value)
# Out:
# market_position_2 -0.5500704130094938
# total_prosumption -0.20688445411929157
# p_grid_imbalance_4 -0.20082524307061037
# p_grid_imbalance_5 -0.19965771091003118
# p_grid_imbalance_6 -0.1898741410199995
# p_grid_imbalance_7 -0.18949083196819744
# p_grid_imbalance_8 -0.1707545183542551
# p_grid_imbalance_3 -0.1700439703725542
# p_grid_imbalance_9 -0.13767335252389387
# hour_of_day_0 -0.13297739689014748
# hour_of_day_23 -0.1315463437510714
# p_grid_imbalance_2 -0.11902423936673918
# market_position_0 -0.11867321541972879
# market_position_1 -0.11767247936394327
# market_position_3 -0.11590329564679515
# market_position_4 -0.11248376196348032
# hour_of_day_22 -0.11103529071189591
# p_temperature_11 -0.09292386092580451
# p_temperature_12 -0.09226401563777044
# hour_of_day_1 -0.09079310131070588
# p_wind_speed_11 -0.08944453456150737
# p_wholesale_price_8 -0.08798314195445102
# market_position_5 -0.08744260812399757
# day_of_week_5 -0.08620901157862822
# p_temperature_13 -0.08529619307490656
# p_temperature_10 -0.08468104777048871
# p_grid_imbalance_10 -0.08375789020415997
# hour_of_day_21 -0.0837340017203182
# p_wind_speed_13 -0.08276527663140734
# p_wholesale_price_7 -0.08274570586021994
# p_wholesale_price_6 -0.08229354788901325
# p_wind_speed_12 -0.0809377798219949
# p_wind_speed_10 -0.08057742779660132
# p_temperature_9 -0.08040490720098578
# day_of_week_6 -0.07963278641138338
# p_temperature_8 -0.07849204446606282
# cleared_orders_energy_2 -0.07637822120005638
# p_wind_speed_14 -0.07564317057202703
# p_temperature_14 -0.07239906165446158
# p_wind_speed_9 -0.072279518612671
# p_wholesale_price_5 -0.07200109571555077
# p_temperature_7 -0.07172612436265183
# p_wholesale_price_9 -0.06978858508831624
# p_wind_speed_8 -0.06846540079613064
# market_position_6 -0.06684871988548909
# p_wind_speed_15 -0.06452835071759265
# p_temperature_6 -0.06286491340758507
# hour_of_day_2 -0.06280247946539219
# p_wind_speed_7 -0.060440467392427984
# p_temperature_5 -0.05703964083702322
# p_temperature_15 -0.056845115063032074
# p_grid_imbalance_1 -0.0544849400569291
# p_wind_speed_6 -0.053966093682051366
# cleared_orders_energy_1 -0.05342172782426538
# p_temperature_4 -0.04935067734922119
# p_wholesale_price_10 -0.04925016153342678
# p_wind_speed_16 -0.04918188750996626
# cleared_orders_energy_4 -0.04853108038144566
# p_wholesale_price_11 -0.047687121886194186
# hour_of_day_20 -0.04763066651761383
# p_wind_speed_5 -0.04755570907028754
# p_temperature_3 -0.04712251179513404
# p_temperature_0 -0.04560019684002218
# cleared_trade_energy_3 -0.04405017234614393
# market_position_8 -0.04379572203675379
# cleared_trade_energy_22 -0.04334711403221096
# p_wind_speed_4 -0.04281799244574527
# p_temperature_2 -0.042514374000221164
# cleared_trade_energy_21 -0.04242951391779742
# cleared_trade_energy_20 -0.04049690083350543
# p_wind_speed_3 -0.04003519449822459
# customer_count -0.03965938723602182
# p_wind_speed_0 -0.03807387117353648
# p_temperature_16 -0.03750212602664081
# cleared_trade_energy_17 -0.03600389270675933
# p_temperature_1 -0.035423394741777824
# cleared_orders_energy_3 -0.03475038889667647
# p_wind_speed_17 -0.03466816061505408
# cleared_trade_energy_1 -0.034248342453571466
# cleared_orders_energy_5 -0.03422553461820676
# p_wholesale_price_4 -0.034103631744314286
# cleared_trade_energy_6 -0.03368020136984069
# market_position_7 -0.03363669597442358
# cleared_trade_energy_16 -0.03194956520082832
# p_wind_speed_19 -0.03098763366904937
# p_wind_speed_2 -0.03081626703931565
# p_temperature_21 -0.030795185558330263
# p_temperature_22 -0.030120337869563727
# cleared_trade_energy_18 -0.029827101403928174
# p_wind_speed_21 -0.029209540235249076
# cleared_trade_energy_5 -0.02868680841769254
# cleared_trade_energy_4 -0.028377343219609892
# cleared_trade_energy_19 -0.02820143868389247
# p_grid_imbalance_11 -0.02819697867246545
# cleared_trade_energy_8 -0.02805644926683421
# p_cloud_cover_15 -0.02709387116710113
# hour_of_day_3 -0.026604869848007306
# p_wind_speed_1 -0.026088523410096875
# p_wind_speed_18 -0.025658454673751278
# cleared_trade_price_16 -0.025605193955958526
# p_temperature_23 -0.025284653887818993
# cleared_trade_energy_2 -0.02468392787678374
# cleared_trade_energy_15 -0.024630246278250587
# cleared_trade_energy_14 -0.02451140771968166
# p_cloud_cover_16 -0.024453960572309474
# p_temperature_17 -0.02438002675086622
# cleared_trade_energy_10 -0.024013329741984557
# cleared_trade_energy_0 -0.02378356083618401
# p_cloud_cover_14 -0.023163591879722525
# cleared_trade_price_12 -0.022260888765241526
# cleared_trade_price_14 -0.02156431024409931
# p_customer_prosumption_11 -0.021411492121564058
# cleared_trade_price_13 -0.020827703683131388
# cleared_trade_energy_11 -0.020264939626579447
# cleared_orders_energy_6 -0.02020296401801269
# p_cloud_cover_13 -0.020185724104838744
# p_cloud_cover_17 -0.020181402992093922
# p_temperature_20 -0.019901606116281823
# p_wholesale_price_12 -0.019039308677653802
# p_temperature_18 -0.018476507014690988
# p_wind_speed_22 -0.01845077265869605
# p_customer_prosumption_12 -0.01832900921021654
# cleared_orders_price_20 -0.018148483575233867
# p_customer_prosumption_20 -0.01798946533791002
# cleared_trade_energy_12 -0.01793313113237438
# cleared_orders_price_21 -0.017902653345645374
# p_wind_speed_20 -0.01757078640335517
# cleared_trade_price_18 -0.017360495051564135
# p_customer_prosumption_15 -0.017246328604698574
# price_16 -0.015736581031824782
# p_temperature_19 -0.015615672166586094
# p_customer_prosumption_14 -0.014970626514162826
# market_position_10 -0.014947348679181368
# cleared_trade_price_17 -0.014469028968656752
# cleared_orders_price_19 -0.014368344942522537
# price_22 -0.013991870065242669
# market_position_9 -0.013529196208654296
# cleared_trade_energy_13 -0.013228700440754922
# price_5 -0.013216528657302497
# market_position_13 -0.013180855809674348
# cleared_trade_energy_9 -0.013154267619946052
# p_customer_prosumption_21 -0.012871502610054625
# p_customer_prosumption_16 -0.012856488654938877
# price_9 -0.01282490235219908
# price_1 -0.012192603704186433
# cleared_orders_energy_23 -0.011827752774104461
# cleared_orders_energy_17 -0.011488652234509138
# market_position_14 -0.011358480102930682
# market_position_17 -0.0112202395430953
# energy_14 -0.010492775000977264
# cleared_orders_price_10 -0.010133261941112989
# cleared_trade_price_10 -0.00970504887822676
# market_position_21 -0.00969944577891491
# energy_6 -0.00963305541106675
# cleared_orders_price_16 -0.009511803378861865
# p_wind_speed_23 -0.009511441238257522
# energy_21 -0.009500036911438775
# cleared_orders_energy_7 -0.008901599504580202
# market_position_19 -0.008872081480986489
# cleared_orders_price_15 -0.008304386595932344
# market_position_23 -0.008192562192243758
# p_customer_prosumption_19 -0.008176821333275406
# p_cloud_cover_18 -0.008103061073551968
# energy_11 -0.007875621633485893
# p_customer_prosumption_13 -0.007731332412427159
# market_position_18 -0.007622488221047204
# cleared_orders_price_23 -0.007510995298385589
# price_24 -0.007344396813395639
# energy_4 -0.007256426779974339
# market_position_16 -0.007000782857147986
# market_position_22 -0.006716018784809861
# cleared_orders_energy_22 -0.006587447454911943
# cleared_orders_energy_8 -0.0063940194166855705
# energy_15 -0.006304773340197233
# cleared_orders_price_8 -0.006231993493331631
# price_23 -0.006010013369673574
# p_customer_prosumption_17 -0.005716304219424268
# p_cloud_cover_12 -0.005517793853194998
# cleared_orders_energy_21 -0.005328390961443083
# cleared_trade_energy_7 -0.005312999663966285
# energy_20 -0.004812323165812949
# price_4 -0.004768558604741785
# cleared_orders_price_11 -0.0047138144949092345
# energy_13 -0.004394085667450997
# p_wholesale_price_3 -0.004218672852237125
# energy_3 -0.004058550893656303
# price_7 -0.003988325090180497
# cleared_orders_energy_19 -0.003910343594138209
# cleared_trade_price_15 -0.0038823345241128498
# price_8 -0.0036384979235585383
# cleared_orders_price_18 -0.0031446298803382393
# price_13 -0.0031225788774309365
# price_12 -0.0030647697365116465
# cleared_orders_price_12 -0.0029024998741918866
# p_cloud_cover_21 -0.002851485856871755
# cleared_orders_energy_9 -0.002850655094845848
# energy_2 -0.0025279532342078466
# cleared_trade_price_20 -0.00251609871650491
# price_19 -0.0023281244888314124
# energy_19 -0.002285312899442319
# market_position_12 -0.002193152138754038
# cleared_orders_price_14 -0.0021694633237303185
# cleared_orders_price_13 -0.00210121453904398
# energy_18 -0.00204136731498307
# p_cloud_cover_11 -0.001710116693752848
# price_17 -0.0011554106736249205
# p_customer_prosumption_22 -0.0010064967502402909
# price_10 -0.00032757013141595826
# energy_8 -0.00014493105301765488
# cleared_trade_price_19 -4.9851101041394375e-05
# market_position_15 4.332231538506271e-05
# cleared_orders_price_22 0.00013143916271291705
# price_2 0.00015762158591053733
# energy_12 0.0001897278459951487
# price_3 0.0006504494917512923
# p_grid_imbalance_15 0.0009275654456995864
# cleared_orders_energy_18 0.0011434227954962067
# p_customer_prosumption_2 0.0012979646184822474
# cleared_orders_energy_15 0.0015515737511789672
# cleared_trade_price_11 0.001593962515252533
# p_wholesale_price_13 0.0016626424945471545
# cleared_orders_price_17 0.0016739229901735237
# p_customer_prosumption_3 0.001684615127869734
# market_position_20 0.0017654764523366896
# p_cloud_cover_20 0.001956902831455166
# cleared_trade_price_21 0.0021477675277360715
# cleared_orders_price_7 0.0024179983903346663
# p_cloud_cover_19 0.0024495372721531237
# p_customer_prosumption_18 0.003117435186726611
# cleared_orders_energy_13 0.0031831952147409323
# hour_of_day_19 0.0032650219449449607
# energy_24 0.004098825980548415
# market_position_11 0.004715441922813075
# energy_17 0.004891750718507255
# cleared_trade_price_9 0.005013906541386928
# price_18 0.005044151987648556
# price_20 0.005925023873366621
# price_11 0.006188883416449602
# energy_1 0.0062354988273888474
# p_wholesale_price_2 0.006264257984717997
# energy_22 0.006998692379761428
# p_grid_imbalance_14 0.007168013130325708
# price_6 0.007468186406827059
# cleared_orders_energy_20 0.007579988196810923
# cleared_orders_energy_14 0.0076791839590066345
# p_grid_imbalance_0 0.008393664074396739
# price_15 0.008428385830407111
# energy_23 0.0087279800878653
# price_21 0.00905971584133303
# p_customer_prosumption_10 0.009306359572188925
# cleared_orders_price_6 0.010155245287620261
# energy_5 0.010584257724354864
# cleared_orders_energy_11 0.010815974735819736
# cleared_orders_price_5 0.011452941985400051
# cleared_trade_price_8 0.011813770347188874
# energy_10 0.011949242736925098
# cleared_orders_energy_12 0.012064649643652588
# p_cloud_cover_9 0.01318084175044375
# cleared_orders_price_9 0.013261167926341551
# energy_16 0.013292337553730708
# price_14 0.013443261165401415
# day_of_week_4 0.013516171173881607
# p_cloud_cover_0 0.013658446689959006
# cleared_orders_energy_10 0.014207158445052262
# p_customer_prosumption_23 0.014253997034662368
# energy_7 0.0147196916131945
# p_cloud_cover_10 0.01497330643621719
# p_grid_imbalance_12 0.015035126634939
# cleared_orders_energy_16 0.015613607217478433
# energy_9 0.015905852444380746
# day_of_week_0 0.017280884650797534
# p_cloud_cover_8 0.0177146205340023
# p_wholesale_price_14 0.018487003843375295
# p_grid_imbalance_13 0.01875119074724939
# cleared_trade_price_1 0.02007600303177381
# cleared_trade_price_7 0.02011811035271315
# cleared_orders_price_4 0.025713994933949342
# p_customer_prosumption_4 0.026460300834755954
# cleared_orders_price_3 0.026977686829701725
# cleared_orders_price_1 0.028394598141257353
# p_cloud_cover_7 0.02878368418369452
# hour_of_day_4 0.02887807675257358
# p_cloud_cover_6 0.029504887131404808
# p_customer_prosumption_1 0.030084631981866887
# p_cloud_cover_3 0.031560881833354065
# p_cloud_cover_22 0.03300237508315057
# p_cloud_cover_2 0.0333901779888071
# day_of_week_3 0.0333928943765293
# hour_of_day_11 0.034165628636834276
# cleared_trade_price_22 0.03480151989023212
# hour_of_day_18 0.035111564965512675
# hour_of_day_15 0.036552144396601746
# p_cloud_cover_23 0.03694082625408163
# timeslot 0.03883284239187538
# hour_of_day_8 0.03893943048075865
# p_cloud_cover_1 0.04055030917664305
# p_cloud_cover_5 0.040655401811820584
# hour_of_day_13 0.04334655968548571
# hour_of_day_9 0.04419700620816509
# hour_of_day_6 0.04518828698382281
# hour_of_day_12 0.04562177088153337
# day_of_week_2 0.04573686101856899
# p_cloud_cover_4 0.04746357739389376
# hour_of_day_16 0.04830485416137298
# cleared_trade_price_6 0.04870420639473589
# p_wholesale_price_1 0.048840470946481224
# hour_of_day_10 0.05080857452530298
# p_customer_prosumption_0 0.05197116786958749
# p_wholesale_price_15 0.0522335086873874
# hour_of_day_17 0.053038774781078254
# day_of_week_1 0.05538490769212014
# hour_of_day_14 0.056418320629015015
# p_grid_imbalance_16 0.05721702048797458
# hour_of_day_7 0.05851414034411186
# cleared_trade_price_5 0.05961915766244929
# p_wholesale_price_23 0.06042781065847536
# wholesale_reward 0.06055773534317472
# p_wholesale_price_16 0.06208365632278046
# hour_of_day_5 0.06306705857550643
# p_wholesale_price_17 0.066614886161647
# p_grid_imbalance_23 0.07045562240677997
# p_customer_prosumption_9 0.07079230303164648
# p_wholesale_price_20 0.07158172114567989
# p_customer_prosumption_5 0.07282386674894836
# p_grid_imbalance_22 0.07654009115171377
# p_wholesale_price_19 0.0774041776620441
# cleared_trade_price_3 0.08142862384884111
# cleared_trade_price_0 0.08257509450500178
# p_wholesale_price_18 0.08471749660533108
# cleared_trade_price_4 0.08620801333126389
# cleared_orders_price_2 0.08856337242042446
# p_grid_imbalance_17 0.08878515042041873
# p_wholesale_price_0 0.08899161586171254
# p_grid_imbalance_21 0.09276521953417187
# p_grid_imbalance_18 0.09300556621044509
# p_wholesale_price_21 0.09397980341308708
# p_grid_imbalance_19 0.10000319595670418
# p_grid_imbalance_20 0.10407482007137984
# p_wholesale_price_22 0.11411243372260997
# cleared_trade_price_2 0.11450537114295804
# p_customer_prosumption_6 0.133274556202647
# p_customer_prosumption_8 0.1372572671506224
# cleared_trade_price_23 0.1418947163927077
# p_customer_prosumption_7 0.16554862225002698
# cleared_trade_energy_23 0.20210261820692163
# sum_mWh 0.27148314891604586
# shaped_return 0.8564897356287012
# balancing_reward 0.9975685511759936
# reward 1.0
# cleared_orders_energy_0 nan
# cleared_orders_price_0 nan

# %%
df2 = pd.DataFrame()
df2["predicted_consumption_mWh"] = df["p_customer_prosumption_0"] /-1000
df2["timeslot"] = df["timeslot"]
df2["market_position_0"] = df["market_position_0"]
df2["sum_mWh"] = df["sum_mWh"]
df2["error_prediction"] = abs(df2["sum_mWh"]) - df2["predicted_consumption_mWh"]
df2
# Out:
#        predicted_consumption_mWh  timeslot  market_position_0    sum_mWh  \
# 0                       3.159721       362           0.000000  64.195619
# 1                       1.030662       363           0.000000  40.904164
# 2                       2.332565       364           0.000000  41.442544
# 3                       2.476563       365          -1.474410  28.667710
# 4                       2.834549       366          17.283201  26.128980
# ...                          ...       ...                ...        ...
# 13708                  14.863338      1833         193.531592  56.755078
# 13709                  14.852021      1834          71.065908  48.955710
# 13710                  15.133340      1835         172.567562  38.700401
# 13711                  14.865160      1836          73.379641  53.906098
# 13712                  14.383041      1837          20.243343  63.405965
#
#        error_prediction
# 0             61.035898
# 1             39.873502
# 2             39.109979
# 3             26.191147
# 4             23.294431
# ...                 ...
# 13708         41.891740
# 13709         34.103689
# 13710         23.567061
# 13711         39.040938
# 13712         49.022924
#
# [13713 rows x 5 columns]

# %% [markdown]
# ### Action analysis

# %%
#f,axs = plt.subplots(1,1,figsize=(25,25))
#for i in range(1):
    #ax = sns.scatterplot(x=action_observation_reward_df[f"price_{i+1}"], y=action_observation_reward_df[f"energy_{i+1}"], data=action_observation_reward_df, hue="balancing_reward", ax=axs)
#    ax = sns.histplot(x=df[f"price_{i+1}"], y=df[f"energy_{i+1}"], data=df, hue="balancing_reward", ax=axs)

# %%
plot_args= {"cut": 0}
f,axs = plt.subplots(1,1,figsize=(25,25))
ax = sns.boxplot(data=df[energy], orient="h")

# %%
f,axs = plt.subplots(1,1,figsize=(25,25))
ax = sns.boxplot(data=df[price],  orient="h")

# %%
f,axs = plt.subplots(6,4,figsize=(25,25) ,sharex=True, sharey=True)

for i in range(0,24,1):
    df_seleciton = df.loc[df[f"price_{i+1}"]<0]

    j = int(i/4)
    j2 = round(i%4)
    axs[j][j2].set_title(f"Buying {i+1}")
    sns.kdeplot(data=df_seleciton[[f"price_{i+1}", f"energy_{i+1}"]], ax=axs[j][j2], bw_adjust=0.3)

# %%
# Selling
from matplotlib.pyplot import title


f,axs = plt.subplots(6,4,figsize=(25,25) ,sharex=True, sharey=True)
for i in range(0,24,1):
    df_seleciton = df.loc[df[f"price_{i+1}"]>0]

    j = int(i/4)
    j2 = round(i%4)
    axs[j][j2].set_title(f"Selling {i+1}")
    sns.kdeplot(data=df_seleciton[[f"price_{i+1}", f"energy_{i+1}"]], ax=axs[j][j2], bw_adjust=0.3)

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import matplotlib_inline
import numpy as np
import pandas as pd
import seaborn as sns

import is3_broker_rl
from is3_broker_rl.api import Action, Observation, Reward

# %matplotlib inline
matplotlib_inline.backend_inline.set_matplotlib_formats("retina")
sns.set_style("whitegrid")

# %%
DATA_DIR = Path(is3_broker_rl.__file__).parent.parent / "data"

# %%
# Papermill parameter cell
# Name of the directory to analyse. Should contain consumption_action.csv and consumption_reward.csv.
ANALYSIS_DIR_NAME = ""

# %%
# Parameters
ANALYSIS_DIR_NAME = "trial3_consumption_training2"

# %%
ANALYSIS_DIR = DATA_DIR / ANALYSIS_DIR_NAME

# %%
df_action = pd.read_csv(ANALYSIS_DIR / "consumption_action.csv")
df_reward = pd.read_csv(ANALYSIS_DIR / "consumption_reward.csv")

# %%
ACTION_VALUE_MAPPING = {a.name: a.value for a in Action}

# %%
# Fixes the issue that the experiment scheduler always assigns the same gameId
def write_unique_game_id(df):
    new_game_start_indices = df[df["timeslot"] < df["timeslot"].shift()].index
    if len(new_game_start_indices) > 0:
        df.loc[: new_game_start_indices[0], "gameId"] = f"game0"
        for i in range(len(new_game_start_indices) - 1):
            df.loc[new_game_start_indices[i] : new_game_start_indices[i + 1], "gameId"] = f"game{i + 1}"
        df.loc[new_game_start_indices[-1] :, "gameId"] = f"game{len(new_game_start_indices)}"

# %%
write_unique_game_id(df_reward)
write_unique_game_id(df_action)

# %%
def plot_action_counts(df_action):
    fig, ax = plt.subplots(figsize=(16, 9))
    sns.countplot(x="action", data=df_action, ax=ax, order=ACTION_VALUE_MAPPING.values())
    ax.set_xticklabels(ACTION_VALUE_MAPPING.keys())
    ax.set_xlabel("Action type")
    ax.set_ylabel("Count")
    ax.set_title("Action distribution")

# %%
plot_action_counts(df_action)

# %%
def plot_action_count_over_time(df_action, df_reward):
    fig, axs = plt.subplots(figsize=(21, 14), nrows=len(ACTION_VALUE_MAPPING), sharey=True)
    action_value_counts = (
        df_action[["gameId", "action"]]
        .groupby(["gameId", "action"], sort=False)
        .size()
        .unstack(fill_value=0)
        .reset_index(drop=True)
    )
    timeslots_per_game = df_reward.groupby("gameId", sort=False).count()["timeslot"].reset_index(drop=True)
    action_per_reward = np.ceil(len(df_reward) / len(df_action))
    action_value_fractions = action_value_counts.divide(timeslots_per_game, axis=0) * action_per_reward

    for i, action_value in enumerate(ACTION_VALUE_MAPPING.values()):
        ax = axs.flat[i]
        sns.lineplot(data=action_value_fractions[action_value], ax=ax)
        ax.set_title(
            f"Fraction of action={list(ACTION_VALUE_MAPPING.keys())[list(ACTION_VALUE_MAPPING.values()).index(action_value)]} over time for each game"
        )
        ax.set_xlabel("Game number")
        ax.set_ylabel("Action count fraction")
        ax.set_ylim((0, action_value_fractions.max().max()))
        ax.set_xticks(action_value_fractions.index)
        ax.margins(x=0)
    fig.tight_layout()

# %%
plot_action_count_over_time(df_action, df_reward)

# %%
def timestep_reg_plot(df_reward, column, window_size=168):
    fig, ax = plt.subplots(figsize=(16, 9))
    sns.lineplot(data=df_reward[column].rolling(window_size).mean(), label=f"Mean {column}", ax=ax)
    sns.regplot(
        x=df_reward.index,
        y=column,
        data=df_reward[[column]].rolling(window_size).mean(),
        scatter=False,
        marker=".",
        ax=ax,
        label="OLS fit",
    )
    ax.vlines(
        df_reward[df_reward["gameId"] != df_reward["gameId"].shift()].index + window_size,
        0,
        1,
        transform=ax.get_xaxis_transform(),
        colors="r",
        alpha=0.2,
        label="New game",
    )
    ax.set_xlabel("Timeslot")
    ax.set_ylabel(column)
    ax.set_title(f"Rolling mean {column} with window size {window_size}")
    ax.legend()

# %%
timestep_reg_plot(df_reward, "consumption_profit")

# %%
timestep_reg_plot(df_reward, "cashPosition")

# %%
def plot_final_cash_position(df_reward):
    fig, ax = plt.subplots(figsize=(16, 9))
    df_final_timeslot = df_reward[df_reward["gameId"].shift(-1) != df_reward["gameId"]].reset_index()
    df_final_timeslot["cashPosition"] = (
        df_final_timeslot["cashPosition"] / df_final_timeslot["timeslot"].max() * df_final_timeslot["timeslot"]
    )
    sns.lineplot(
        x=df_final_timeslot.index, y="cashPosition", data=df_final_timeslot, label="Final cash position", ax=ax
    )
    sns.regplot(
        x=df_final_timeslot.index,
        y="cashPosition",
        data=df_final_timeslot,
        scatter=False,
        marker=".",
        ax=ax,
        label="OLS fit",
    )
    ax.set_xlabel("Game")
    ax.set_ylabel("Cash position")
    ax.set_title(f"Final cash position per game (adjusted for game length)")
    ax.set_xticks(df_final_timeslot.index)
    ax.margins(x=0)
    ax.legend()

# %%
plot_final_cash_position(df_reward)

# %%
timestep_reg_plot(df_reward, "capacity_costs")

# %%
timestep_reg_plot(df_reward, "consumption_fees")

# %%
timestep_reg_plot(df_reward, "balancing_costs")

# %%
timestep_reg_plot(df_reward, "reward", window_size=3500)

# %%
def plot_mean_episode_reward_reg(df_reward, df_action):
    window_size = 60
    fig, ax = plt.subplots(figsize=(21, 11))
    df_mean_episode_reward = (
        df_reward.groupby("episode_id", sort=False).mean().reset_index(drop=True).rolling(window_size).mean()
    )
    sns.lineplot(
        x=df_mean_episode_reward.index,
        y="reward",
        data=df_mean_episode_reward,
        label="Mean episode reward",
        ax=ax,
    )
    sns.regplot(
        x=df_mean_episode_reward.index,
        y="reward",
        data=df_mean_episode_reward,
        scatter=False,
        marker=".",
        ax=ax,
        label="OLS fit",
    )
    df_episode_game_id = df_reward.groupby("episode_id", sort=False)["gameId"].first().reset_index()
    ax.vlines(
        df_episode_game_id[df_episode_game_id["gameId"].shift() != df_episode_game_id["gameId"]].index + window_size,
        0,
        1,
        transform=ax.get_xaxis_transform(),
        colors="r",
        alpha=0.3,
        label="New game",
    )
    ax.set_xlabel("Episode")
    ax.set_ylabel("Aggregated reward")
    ax.legend()
    ax.set_title(
        f"Mean episode reward (N_EPISODES: {df_reward['episode_id'].nunique()}, N_TIMESTEPS: {len(df_action)})"
    )
    ax.margins(x=0)

# %%
plot_mean_episode_reward_reg(df_reward, df_action)

# %%
def plot_mean_reward_per_action(df_reward):
    fig, ax = plt.subplots(figsize=(21, 11))
    df_reward = df_reward.copy().dropna()  # Avoid overwriting original df
    df_reward["last_action"] = df_reward["last_action"].astype(np.uint8)
    mean_reward_per_action = df_reward[["last_action", "reward"]].groupby("last_action").mean()
    sns.barplot(
        x=mean_reward_per_action.index,
        y="reward",
        data=mean_reward_per_action,
        ax=ax,
        order=ACTION_VALUE_MAPPING.values(),
    )
    ax.set_xticklabels(ACTION_VALUE_MAPPING.keys())
    ax.set_xlabel("Action")
    ax.set_ylabel("Mean reward associated with the action")
    ax.set_title(f"Mean reward per action")

# %%
plot_mean_reward_per_action(df_reward)

# %%
def plot_reward_correlation_matrix(df_reward):
    fig, ax = plt.subplots(figsize=(14, 14))
    corr = df_reward.drop(columns=["timeslot", "gameId", *Reward.__fields__.keys()]).corr()
    mask = np.triu(np.ones_like(corr, dtype=bool))
    cmap = sns.diverging_palette(230, 20, as_cmap=True)
    sns.heatmap(corr, mask=mask, cmap=cmap, annot=True, square=True, ax=ax)
    ax.set_title("Correlation of state space and reward function")

# %%
plot_reward_correlation_matrix(df_reward)

# %%
from ray.rllib.agents.dqn import DQNTrainer

from is3_broker_rl.model.consumption_tariff_config import dqn_config

dqn_rllib = DQNTrainer(config=dqn_config)
# Out:
# /Users/phipag/Library/Caches/pypoetry/virtualenvs/is3-broker-rl-PYz1kpZp-py3.9/lib/python3.9/site-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(
# 2022-08-09 11:24:10,265	DEBUG rollout_worker.py:1770 -- Creating policy for default_policy
# 2022-08-09 11:24:10,267	DEBUG catalog.py:805 -- Created preprocessor <ray.rllib.models.preprocessors.NoPreprocessor object at 0x1742e85b0>: Box([ 3.6000000e+02 -3.4028235e+38 -3.4028235e+38 -3.4028235e+38
#   0.0000000e+00  0.0000000e+00 -3.4028235e+38  0.0000000e+00
#   0.0000000e+00  0.0000000e+00  0.0000000e+00], [4.0000000e+03 3.4028235e+38 3.4028235e+38 3.4028235e+38 1.0000000e+03
#  1.0000000e+03 3.4028235e+38 1.0000000e+00 1.0000000e+00 1.0000000e+06
#  4.0000000e+00], (11,), float32) -> (11,)
# 2022-08-09 11:24:10,274	INFO eager_tf_policy.py:343 -- TF-eager Policy (worker=local) running on CPU.
# 2022-08-09 11:24:10,367	INFO rollout_worker.py:1793 -- Built policy map: {}
# 2022-08-09 11:24:10,368	INFO rollout_worker.py:1794 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x1742e85b0>}
# 2022-08-09 11:24:10,368	INFO rollout_worker.py:670 -- Built filter map: {'default_policy': MeanStdFilter([11], True, True, None, (n=0, mean_mean=0.0, mean_std=0.0), (n=0, mean_mean=0.0, mean_std=0.0))}
# 2022-08-09 11:24:11,379	INFO policy_server_input.py:112 -- Starting connector server at 1.0.0.127.in-addr.arpa:9900
# 2022-08-09 11:24:11,382	DEBUG rollout_worker.py:783 -- Created rollout worker with env None (None), policies {}
# Install gputil for GPU system monitoring.

# %%
dqn_rllib.restore(
    "/Users/phipag/Git/powertac/is3-broker-rl/data/trial3_consumption_training2/DQN_Consumption_Test10/DQN_None_b7d16_00000_0_2022-07-23_09-34-59/checkpoint_000125/checkpoint-125"
)
# Out:
# 2022-08-09 11:24:13,359	INFO services.py:1470 -- View the Ray dashboard at http://127.0.0.1:8265
# 2022-08-09 11:24:14,504	INFO trainable.py:588 -- Restored on 127.0.0.1 from checkpoint: /Users/phipag/Git/powertac/is3-broker-rl/data/trial3_consumption_training2/DQN_Consumption_Test10/DQN_None_b7d16_00000_0_2022-07-23_09-34-59/checkpoint_000125/checkpoint-125
# 2022-08-09 11:24:14,505	INFO trainable.py:597 -- Current state after restoring: {'_iteration': 125, '_timesteps_total': 2000, '_time_total': 111277.2490901947, '_episodes_total': 0}

# %%
df_action[Observation.__fields__.keys()].drop(columns=["gameId"])
# Out:
#       timeslot  gridImbalance  ownImbalanceKwh  customerCount  \
# 0          374    -138.230715      1636.368652              0
# 1          388  -36253.702093    -44076.615699         100448
# 2          402  -39890.966528    -31484.806440         100758
# 3          416    2441.668892     -2575.448103         100302
# 4          430  -15663.392203     12657.757463           2296
# ...        ...            ...              ...            ...
# 6176      1214    6201.959477      1404.645508              0
# 6177      1228  -10828.146592        13.594727              0
# 6178      1242    3705.237971      3085.382324              0
# 6179      1256  -14052.596788      1210.546875              0
# 6180      1270  -20752.732372      3422.024414              0
#
#       customerNetDemand  marketPosition  wholesalePrice  ownWholesalePrice  \
# 0              0.000000               0       52.462393          60.378212
# 1         -45340.624000               3       63.825966          13.603424
# 2         -44385.485581               3       65.168676          33.333333
# 3         -47789.444217               3       70.372666          45.240090
# 4           -424.827303               2       83.018436         169.391568
# ...                 ...             ...             ...                ...
# 6176           0.000000               2       35.922608          39.043034
# 6177           0.000000               2       35.971124          35.818898
# 6178           0.000000               2       36.840556          43.145896
# 6179           0.000000               2       36.584336           5.970550
# 6180           0.000000               2       37.556684          42.442856
#
#        cashPosition  consumptionShare  productionShare
# 0       2048.383936          0.000000         0.000000
# 1    -173160.872226          0.996949         0.000000
# 2    -264128.965897          0.999860         0.521836
# 3    -413376.890785          0.995912         0.830930
# 4    -328483.977826          0.021335         0.923033
# ...             ...               ...              ...
# 6176 -359336.592879          0.000000         0.000000
# 6177 -358235.499317          0.000000         0.000000
# 6178 -357735.456745          0.000000         0.000000
# 6179 -355827.249625          0.000000         0.000000
# 6180 -352821.255654          0.000000         0.000000
#
# [6181 rows x 11 columns]

# %%
dqn_rllib.compute_action(df_action[Observation.__fields__.keys()].drop(columns=["gameId"]).iloc[4])
# Out:
# 1
